# %% [markdown]
# **Retrieval-Augmented Generation (RAG)** is a method that integrates information retrieval to give generative language models additional information.
#
# **A typical RAG pipeline comprises of 2 main components:**
#
# 1. a **Retriever Module** that first selects relevant documents or pieces of information from a large corpus based on the input query,
# 2. an **Answer Generation Module** that produces more accurate and contextually relevant responses.

# %% [markdown]
# #### Steps to implement a RAG pipeline (Part 1/2):
# 1. Indexing Documents
#
# 2. Creating Embeddings
#
# 3. Create a vector store and store embeddings

# %%
from dotenv import load_dotenv
from colorama import Fore
import warnings
warnings.filterwarnings("ignore")

load_dotenv()
# Out:
# True

# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain==0.2.5
#   Downloading langchain-0.2.5-py3-none-any.whl (974 kB)
#      |████████████████████████████████| 974 kB 5.8 MB/s eta 0:00:01
# Collecting langchain-community==0.2.5
#   Downloading langchain_community-0.2.5-py3-none-any.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 17.0 MB/s eta 0:00:01
# Collecting langchain-core==0.2.7
#   Downloading langchain_core-0.2.7-py3-none-any.whl (315 kB)
#      |████████████████████████████████| 315 kB 8.0 MB/s eta 0:00:01
# Collecting langchain-openai==0.1.8
#   Downloading langchain_openai-0.1.8-py3-none-any.whl (38 kB)
# Collecting langchain-text-splitters==0.2.1
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Collecting openai==1.34.0
#   Downloading openai-1.34.0-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 43.1 MB/s eta 0:00:01
# Collecting bs4==0.0.2
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Collecting chromadb==0.5.0
#   Downloading chromadb-0.5.0-py3-none-any.whl (526 kB)
#      |████████████████████████████████| 526 kB 37.5 MB/s eta 0:00:01
# Collecting python-dotenv==1.0.0
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting colorama==0.4.6
#   Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting tqdm==4.66.4
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 10.8 MB/s eta 0:00:01
# Collecting tiktoken==0.7.0
#   Downloading tiktoken-0.7.0-cp39-cp39-macosx_10_9_x86_64.whl (961 kB)
#      |████████████████████████████████| 961 kB 29.5 MB/s eta 0:00:01
# Collecting langsmith<0.2.0,>=0.1.17
#   Downloading langsmith-0.1.83-py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 13.9 MB/s eta 0:00:01
# Collecting PyYAML>=5.3
#   Downloading PyYAML-6.0.1-cp39-cp39-macosx_10_9_x86_64.whl (197 kB)
#      |████████████████████████████████| 197 kB 13.8 MB/s eta 0:00:01
# Collecting SQLAlchemy<3,>=1.4
#   Downloading SQLAlchemy-2.0.31-cp39-cp39-macosx_10_9_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 25.1 MB/s eta 0:00:01
# Collecting numpy<2,>=1
#   Using cached numpy-1.26.4-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting tenacity<9.0.0,>=8.1.0
#   Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Collecting requests<3,>=2
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 9.5 MB/s  eta 0:00:01
# Collecting pydantic<3,>=1
#   Downloading pydantic-2.8.2-py3-none-any.whl (423 kB)
#      |████████████████████████████████| 423 kB 49.2 MB/s eta 0:00:01
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.9.5-cp39-cp39-macosx_10_9_x86_64.whl (401 kB)
#      |████████████████████████████████| 401 kB 7.2 MB/s eta 0:00:01
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/sandramada/Library/Python/3.9/lib/python/site-packages (from langchain-core==0.2.7->-r requirements.txt (line 3)) (24.1)
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/sandramada/Library/Python/3.9/lib/python/site-packages (from openai==1.34.0->-r requirements.txt (line 6)) (4.12.2)
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.4.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 8.0 MB/s  eta 0:00:01
# Collecting sniffio
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting httpx<1,>=0.23.0
#   Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 10.6 MB/s eta 0:00:01
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.64.1-cp39-cp39-macosx_10_9_universal2.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 22.8 MB/s eta 0:00:01
# Collecting orjson>=3.9.12
#   Downloading orjson-3.10.6-cp39-cp39-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (250 kB)
#      |████████████████████████████████| 250 kB 17.2 MB/s eta 0:00:01
# Collecting chroma-hnswlib==0.7.3
#   Downloading chroma_hnswlib-0.7.3-cp39-cp39-macosx_10_9_x86_64.whl (219 kB)
#      |████████████████████████████████| 219 kB 44.3 MB/s eta 0:00:01
# Collecting fastapi>=0.95.2
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      |████████████████████████████████| 91 kB 15.9 MB/s eta 0:00:01
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 41.3 MB/s eta 0:00:01
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 2.5 MB/s  eta 0:00:01
# Collecting build>=1.0.3
#   Downloading build-1.2.1-py3-none-any.whl (21 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.1.3-cp39-abi3-macosx_10_12_universal2.whl (506 kB)
#      |████████████████████████████████| 506 kB 26.0 MB/s eta 0:00:01
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.18.1-cp39-cp39-macosx_11_0_universal2.whl (15.9 MB)
#      |████████████████████████████████| 15.9 MB 19.7 MB/s eta 0:00:01
# Collecting mmh3>=4.0.1
#   Downloading mmh3-4.1.0-cp39-cp39-macosx_10_9_x86_64.whl (29 kB)
# Collecting importlib-resources
#   Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Collecting posthog>=2.4.0
#   Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 796 kB/s  eta 0:00:01
# Collecting overrides>=7.3.1
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 13.8 MB/s eta 0:00:01
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl (11 kB)
# Collecting typer>=0.9.0
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 11.4 MB/s eta 0:00:01
# Collecting tokenizers>=0.13.2
#   Downloading tokenizers-0.19.1-cp39-cp39-macosx_10_12_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 14.2 MB/s eta 0:00:01
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      |████████████████████████████████| 67 kB 10.0 MB/s eta 0:00:01
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/mr/t4wc0l8532l_zr1d02nrh8vr0000gn/T/pip-build-env-fbs3_182/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/mr/t4wc0l8532l_zr1d02nrh8vr0000gn/T/pip-build-env-fbs3_182/normal/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/mr/t4wc0l8532l_zr1d02nrh8vr0000gn/T/pip-build-env-fbs3_182/normal'
#   WARNING: Value for prefixed-purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/mr/t4wc0l8532l_zr1d02nrh8vr0000gn/T/pip-build-env-fbs3_182/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Value for prefixed-platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
#   distutils: /private/var/folders/mr/t4wc0l8532l_zr1d02nrh8vr0000gn/T/pip-build-env-fbs3_182/overlay/lib/python3.9/site-packages
#   sysconfig: /Library/Python/3.9/site-packages
#   WARNING: Additional context:
#   user = False
#   home = None
#   root = None
#   prefix = '/private/var/folders/mr/t4wc0l8532l_zr1d02nrh8vr0000gn/T/pip-build-env-fbs3_182/overlay'
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 34.6 MB/s eta 0:00:01
# Collecting regex>=2022.1.18
#   Downloading regex-2024.5.15-cp39-cp39-macosx_10_9_x86_64.whl (281 kB)
#      |████████████████████████████████| 281 kB 26.0 MB/s eta 0:00:01
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.1-cp39-cp39-macosx_10_9_x86_64.whl (55 kB)
#      |████████████████████████████████| 55 kB 11.9 MB/s eta 0:00:01
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.5-cp39-cp39-macosx_10_9_x86_64.whl (30 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.4-cp39-cp39-macosx_10_9_x86_64.whl (83 kB)
#      |████████████████████████████████| 83 kB 5.3 MB/s  eta 0:00:01
# Collecting attrs>=17.3.0
#   Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Collecting idna>=2.8
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 12.0 MB/s eta 0:00:01
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/sandramada/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai==1.34.0->-r requirements.txt (line 6)) (1.2.1)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/sandramada/Library/Python/3.9/lib/python/site-packages (from build>=1.0.3->chromadb==0.5.0->-r requirements.txt (line 8)) (8.0.0)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 11.8 MB/s eta 0:00:01
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jinja2>=2.11.2
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 30.6 MB/s eta 0:00:01
# Collecting starlette<0.38.0,>=0.37.2
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 662 kB/s  eta 0:00:01
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1
#   Downloading ujson-5.10.0-cp39-cp39-macosx_10_9_x86_64.whl (55 kB)
#      |████████████████████████████████| 55 kB 5.1 MB/s eta 0:00:011
# Collecting email_validator>=2.0.0
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Collecting fastapi-cli>=0.0.2
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Collecting python-multipart>=0.0.7
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting dnspython>=2.0.0
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      |████████████████████████████████| 307 kB 12.7 MB/s eta 0:00:01
# Collecting certifi
#   Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 56.9 MB/s eta 0:00:01
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/sandramada/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb==0.5.0->-r requirements.txt (line 8)) (3.19.2)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.5-cp39-cp39-macosx_10_9_x86_64.whl (14 kB)
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 12.8 MB/s eta 0:00:01
# Requirement already satisfied: urllib3>=1.24.2 in /Users/sandramada/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 8)) (1.26.6)
# Collecting oauthlib>=3.2.2
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 40.9 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/sandramada/Library/Python/3.9/lib/python/site-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 8)) (2.9.0.post0)
# Collecting google-auth>=1.0.1
#   Downloading google_auth-2.31.0-py2.py3-none-any.whl (194 kB)
#      |████████████████████████████████| 194 kB 23.0 MB/s eta 0:00:01
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: six>=1.9.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb==0.5.0->-r requirements.txt (line 8)) (1.15.0)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 25.7 MB/s eta 0:00:01
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 7.8 MB/s  eta 0:00:01
# Collecting flatbuffers
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting sympy
#   Downloading sympy-1.12.1-py3-none-any.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 34.0 MB/s eta 0:00:01
# Collecting protobuf
#   Downloading protobuf-5.27.2-cp38-abi3-macosx_10_9_universal2.whl (412 kB)
#      |████████████████████████████████| 412 kB 27.9 MB/s eta 0:00:01
# Collecting deprecated>=1.2.6
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata>=4.6
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Collecting wrapt<2,>=1.10
#   Downloading wrapt-1.16.0-cp39-cp39-macosx_10_9_x86_64.whl (37 kB)
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
#      |████████████████████████████████| 220 kB 12.4 MB/s eta 0:00:01
# Collecting opentelemetry-proto==1.25.0
#   Downloading opentelemetry_proto-1.25.0-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 2.6 MB/s  eta 0:00:01
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Collecting protobuf
#   Using cached protobuf-4.25.3-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Collecting opentelemetry-util-http==0.46b0
#   Downloading opentelemetry_util_http-0.46b0-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation==0.46b0
#   Downloading opentelemetry_instrumentation-0.46b0-py3-none-any.whl (29 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0
#   Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
#      |████████████████████████████████| 130 kB 31.3 MB/s eta 0:00:01
# Collecting opentelemetry-instrumentation-asgi==0.46b0
#   Downloading opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl (14 kB)
# Requirement already satisfied: setuptools>=16.0 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb==0.5.0->-r requirements.txt (line 8)) (58.0.4)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting pyasn1<0.7.0,>=0.4.6
#   Downloading pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 12.1 MB/s eta 0:00:01
# Collecting pydantic-core==2.20.1
#   Downloading pydantic_core-2.20.1-cp39-cp39-macosx_10_12_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 2.0 MB/s eta 0:00:01
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp39-cp39-macosx_10_9_x86_64.whl (122 kB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-3.0.3-cp39-cp39-macosx_11_0_universal2.whl (269 kB)
#      |████████████████████████████████| 269 kB 29.1 MB/s eta 0:00:01
# Collecting huggingface-hub<1.0,>=0.16.4
#   Downloading huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
#      |████████████████████████████████| 402 kB 8.6 MB/s eta 0:00:01
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#      |████████████████████████████████| 177 kB 54.7 MB/s eta 0:00:01
# Collecting filelock
#   Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Collecting rich>=10.11.0
#   Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Collecting click>=8.0.0
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sandramada/Library/Python/3.9/lib/python/site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb==0.5.0->-r requirements.txt (line 8)) (2.18.0)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.19.0-cp39-cp39-macosx_10_9_x86_64.whl (808 kB)
#      |████████████████████████████████| 808 kB 8.3 MB/s eta 0:00:01
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.22.0-cp39-cp39-macosx_10_12_x86_64.whl (395 kB)
#      |████████████████████████████████| 395 kB 13.7 MB/s eta 0:00:01
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.1-cp39-cp39-macosx_10_9_x86_64.whl (79 kB)
#      |████████████████████████████████| 79 kB 15.5 MB/s eta 0:00:01
# Collecting websockets>=10.4
#   Downloading websockets-12.0-cp39-cp39-macosx_10_9_x86_64.whl (121 kB)
#      |████████████████████████████████| 121 kB 24.0 MB/s eta 0:00:01
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 14.4 MB/s eta 0:00:01
# Collecting mpmath<1.4.0,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (PEP 517) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53739 sha256=b4cace85b293c05312c4096a9ec4cc6e5b9e58bd101492b9d371ecfaaa07ff55
#   Stored in directory: /Users/sandramada/Library/Caches/pip/wheels/f7/02/64/d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: wrapt, pydantic-core, mdurl, idna, charset-normalizer, certifi, annotated-types, sniffio, requests, pydantic, orjson, markdown-it-py, jsonpointer, importlib-metadata, deprecated, tenacity, shellingham, rich, PyYAML, pyasn1, protobuf, opentelemetry-api, multidict, langsmith, jsonpatch, h11, frozenlist, click, anyio, yarl, websockets, watchfiles, uvloop, uvicorn, typer, tqdm, rsa, python-dotenv, pyasn1-modules, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, opentelemetry-instrumentation, oauthlib, mypy-extensions, mpmath, MarkupSafe, langchain-core, humanfriendly, httptools, httpcore, greenlet, fsspec, filelock, dnspython, cachetools, attrs, async-timeout, asgiref, aiosignal, websocket-client, ujson, typing-inspect, tomli, sympy, starlette, SQLAlchemy, soupsieve, requests-oauthlib, regex, python-multipart, pyproject-hooks, opentelemetry-sdk, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-common, numpy, monotonic, marshmallow, langchain-text-splitters, jinja2, huggingface-hub, httpx, grpcio, googleapis-common-protos, google-auth, flatbuffers, fastapi-cli, email-validator, distro, coloredlogs, backoff, aiohttp, tokenizers, tiktoken, pypika, posthog, overrides, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, openai, onnxruntime, mmh3, langchain, kubernetes, importlib-resources, fastapi, dataclasses-json, chroma-hnswlib, build, beautifulsoup4, bcrypt, langchain-openai, langchain-community, colorama, chromadb, bs4
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 8.0.0
#     Uninstalling importlib-metadata-8.0.0:
#       Successfully uninstalled importlib-metadata-8.0.0
# Successfully installed MarkupSafe-2.1.5 PyYAML-6.0.1 SQLAlchemy-2.0.31 aiohttp-3.9.5 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.4.0 asgiref-3.8.1 async-timeout-4.0.3 attrs-23.2.0 backoff-2.2.1 bcrypt-4.1.3 beautifulsoup4-4.12.3 bs4-0.0.2 build-1.2.1 cachetools-5.3.3 certifi-2024.7.4 charset-normalizer-3.3.2 chroma-hnswlib-0.7.3 chromadb-0.5.0 click-8.1.7 colorama-0.4.6 coloredlogs-15.0.1 dataclasses-json-0.6.7 deprecated-1.2.14 distro-1.9.0 dnspython-2.6.1 email-validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 filelock-3.15.4 flatbuffers-24.3.25 frozenlist-1.4.1 fsspec-2024.6.1 google-auth-2.31.0 googleapis-common-protos-1.63.2 greenlet-3.0.3 grpcio-1.64.1 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 huggingface-hub-0.23.4 humanfriendly-10.0 idna-3.7 importlib-metadata-7.1.0 importlib-resources-6.4.0 jinja2-3.1.4 jsonpatch-1.33 jsonpointer-3.0.0 kubernetes-30.1.0 langchain-0.2.5 langchain-community-0.2.5 langchain-core-0.2.7 langchain-openai-0.1.8 langchain-text-splitters-0.2.1 langsmith-0.1.83 markdown-it-py-3.0.0 marshmallow-3.21.3 mdurl-0.1.2 mmh3-4.1.0 monotonic-1.6 mpmath-1.3.0 multidict-6.0.5 mypy-extensions-1.0.0 numpy-1.26.4 oauthlib-3.2.2 onnxruntime-1.18.1 openai-1.34.0 opentelemetry-api-1.25.0 opentelemetry-exporter-otlp-proto-common-1.25.0 opentelemetry-exporter-otlp-proto-grpc-1.25.0 opentelemetry-instrumentation-0.46b0 opentelemetry-instrumentation-asgi-0.46b0 opentelemetry-instrumentation-fastapi-0.46b0 opentelemetry-proto-1.25.0 opentelemetry-sdk-1.25.0 opentelemetry-semantic-conventions-0.46b0 opentelemetry-util-http-0.46b0 orjson-3.10.6 overrides-7.7.0 posthog-3.5.0 protobuf-4.25.3 pyasn1-0.6.0 pyasn1-modules-0.4.0 pydantic-2.8.2 pydantic-core-2.20.1 pypika-0.48.9 pyproject-hooks-1.1.0 python-dotenv-1.0.0 python-multipart-0.0.9 regex-2024.5.15 requests-2.32.3 requests-oauthlib-2.0.0 rich-13.7.1 rsa-4.9 shellingham-1.5.4 sniffio-1.3.1 soupsieve-2.5 starlette-0.37.2 sympy-1.12.1 tenacity-8.5.0 tiktoken-0.7.0 tokenizers-0.19.1 tomli-2.0.1 tqdm-4.66.4 typer-0.12.3 typing-inspect-0.9.0 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websocket-client-1.8.0 websockets-12.0 wrapt-1.16.0 yarl-1.9.4
# WARNING: You are using pip version 21.2.4; however, version 24.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. Load and split documents

# %%
from langchain_community.document_loaders import TextLoader 
from langchain.text_splitter import CharacterTextSplitter 

def load_documents():
    """Load a file from path, split it into chunks, embed each chunk and load it into the vector store."""
    loader = TextLoader("./docs/user-manual.txt")
    raw_text = loader.load()
    text_splitter = CharacterTextSplitter(chunk_size=100, chunk_overlap=0, separator="\n\n")
    return text_splitter.split_documents(raw_text)

documents = load_documents()
print(f"Loaded {len(documents)} documents")
# Out:
# Created a chunk of size 198, which is longer than the specified 100
# Created a chunk of size 390, which is longer than the specified 100
# Created a chunk of size 232, which is longer than the specified 100
# Created a chunk of size 252, which is longer than the specified 100
# Created a chunk of size 221, which is longer than the specified 100
# Created a chunk of size 280, which is longer than the specified 100
# Created a chunk of size 133, which is longer than the specified 100
# Loaded 8 documents

# %% [markdown]
# 2. Create vector store and store embeddings

# %%
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma
from openai import OpenAI
import os

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

def get_embedding(text_to_embed):
    response = client.embeddings.create(
        model= "text-embedding-ada-002",
        input=[text_to_embed]
    )
    print(response.data[0].embedding)

def load_embeddings(user_query, documents):
    """Create a vector store from a set of documents."""
    embeddings = OpenAIEmbeddings()
    db = Chroma.from_documents(documents, embeddings)
    get_embedding(user_query)
    _ = [get_embedding(doc.page_content) for doc in documents]
    return db.as_retriever()

retriever = load_embeddings("I have an error code E2", documents)
# Out:
# [-0.015627305954694748, -0.0038546891883015633, -0.015446563251316547, -0.024010995402932167, -0.028390534222126007, 0.014181363396346569, -0.023232409730553627, -0.010239779017865658, -0.003701752983033657, -0.00817513931542635, 0.007980492897331715, 0.0031612622551620007, 0.0014546324964612722, -0.005293680354952812, -0.0187972579151392, 0.00027133154799230397, 0.006451129913330078, 0.01373645756393671, 0.012652000412344933, -0.005749013740569353, -0.004056286998093128, 0.0016136515187099576, -0.013812926597893238, -0.006944697350263596, 0.006013176403939724, -0.014487235806882381, 0.003216875484213233, -0.017420832067728043, -0.016405891627073288, -0.014807011932134628, 0.012777130119502544, -0.026916783303022385, -0.022968247532844543, -0.043656352907419205, -0.028181985020637512, -0.004876581486314535, -0.019979039207100868, 0.001525886938907206, 0.022008920088410378, -0.01136594545096159, 0.04852250963449478, 0.013131664134562016, -0.0107681043446064, -0.010705539025366306, -0.020576881244778633, 0.014278686605393887, -0.013013486750423908, 0.01550217717885971, -0.016002696007490158, 0.03105996735394001, -0.0007055923342704773, -0.018922388553619385, -0.02196720987558365, -0.03545340895652771, -0.005015614442527294, 0.008891158737242222, -0.027250463142991066, -0.012693710625171661, 0.0013946745311841369, 0.0024782628752291203, -0.01751815527677536, -0.023844154551625252, -0.007994395680725574, -0.001458108308725059, -0.009509855881333351, 0.004737548530101776, -0.0026850742287933826, -0.01077505573630333, -0.008501866832375526, -0.0035766232758760452, 0.006350331008434296, 0.0019273445941507816, -0.02704191394150257, 0.008856400847434998, 0.020521266385912895, -0.0026051304303109646, -0.031282421201467514, -0.005227639805525541, 0.034063078463077545, -0.014626269228756428, 0.0187972579151392, -0.03181074559688568, -0.02715313993394375, 0.004904388450086117, 0.015808049589395523, -0.014320396818220615, -0.001270413864403963, 0.0025790617801249027, -0.024372480809688568, -0.009224837645888329, 0.03459140285849571, 0.039680011570453644, 0.005832433234900236, 0.010198068805038929, -0.0033802392426878214, 0.007320086006075144, -0.0023513950873166323, 0.02070201002061367, 0.0170732494443655, -0.01511288434267044, -0.007938782684504986, -0.0024104842450469732, -0.006729195825755596, -0.00877298042178154, -0.021188626065850258, -0.0001448984257876873, -0.000686475308
784992754459381, 0.022972257807850838, -0.008778496645390987, -0.000261011125985533, 0.010345382615923882, 0.004395804367959499, 0.011722144670784473, -0.009978245943784714, -0.0068772537633776665, -0.017438985407352448, 0.03296361491084099, 0.01990404538810253, 0.0024683375377207994, 0.003550079185515642, 0.024781715124845505, 0.027613911777734756, -0.019668027758598328, -0.006198707036674023, 0.009034181013703346, -0.006615013349801302, 0.016219567507505417, -0.005710284225642681, 0.003461573040112853, 0.004310576245188713, 0.028557976707816124, 0.0068772537633776665, -0.0195500198751688, ...

# %% [markdown]
# #### Steps to implement a RAG pipeline (Part 2/2):
# 1. Define a prompt
#
# 2. Create and run the retrieval chain

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts.chat import (
    HumanMessagePromptTemplate,
    SystemMessagePromptTemplate,
)
from langchain.prompts import ChatPromptTemplate, PromptTemplate

prompt: str = "You are a customer support specialist who answers questions {question} and assist users with general inquiries"
prompt_template = PromptTemplate.from_template(prompt)

template: str = """/
    You are a customer support specialist /
    question: {question}. You assist users with general inquiries based on {context} /
    and  technical issues. /
    """
system_message_prompt = SystemMessagePromptTemplate.from_template(template)
human_message_prompt = HumanMessagePromptTemplate.from_template(
    input_variables=["question", "context"],
    template="{question}",
)
chat_prompt_template = ChatPromptTemplate.from_messages(
    [system_message_prompt, human_message_prompt]
)

model = ChatOpenAI()

# %% [markdown]
# 2. Create and run the chain

# %% [markdown]
# without RAG

# %%
from langchain.schema import StrOutputParser
from langchain.schema.runnable import RunnablePassthrough

def generate_response(retriever, query):
    """Generate a response using the retriever and the query."""
    # Create a prompt template using a template from the config module and input variables
    # representing the context and question.
    # create the prompt
    chain = (
        {"question": RunnablePassthrough()} 
        | prompt 
        | model 
        | StrOutputParser()
    )
    return chain.invoke(query)

response = generate_response(retriever, "I have an error code E2")
print(f"{Fore.GREEN}{response}{Fore.RESET}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 12
#       9     chain = {"question": RunnablePassthrough()} | prompt | model | StrOutputParser()
#      10     return chain.invoke(query)
# ---> 12 response = generate_response(retriever, "I have an error code E2")
#      13 print(f"{Fore.GREEN}{response}{Fore.RESET}")
#
# Cell In[29], line 9, in generate_response(retriever, query)
#       5 """Generate a response using the retriever and the query."""
#       6 # Create a prompt template using a template from the config module and input variables
#       7 # representing the context and question.
#       8 # create the prompt
# ----> 9 chain = {"question": RunnablePassthrough()} | prompt | model | StrOutputParser()
#      10 return chain.invoke(query)
#
# TypeError: unsupported operand type(s) for |: 'dict' and 'str'

# %% [markdown]
# with RAG

# %%
from langchain.schema import StrOutputParser
from langchain.schema.runnable import RunnablePassthrough

def generate_response(retriever, query):
    """Generate a response using the retriever and the query."""
    # Create a prompt template using a template from the config module and input variables
    # representing the context and question.
    # create the prompt
    chain = (
        {"context": retriever, "question": RunnablePassthrough()} 
        | chat_prompt_template 
        | model 
        | StrOutputParser()
    )
    return chain.invoke(query)

response = generate_response(retriever, "I have an error code E2")
print(f"{Fore.GREEN}{response}{Fore.RESET}")
